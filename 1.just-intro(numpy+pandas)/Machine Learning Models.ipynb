# %% [markdown]
# file:///home/metal-machine/Documents/machine-learning20/research/Your%20First%20Machine%20Learning%20Project%20in%20Python%20Step-By-Step%20-%20Machine%20Learning%20Mastery.html
#
# How to Do machine Learning?
#
# #Applying Machine Learning models to your Data/Data-set is most easy thing to do.
# To Do you just have to do following three(Actually two) steps.
# 1. Download a Data-Set.
# 2.Choose models which you feel should be helpful in on that data.
# 3. Apply those models :D Bingo!!! You are DataScientist and Machine Learning expert.
#
# Here is the real story:
# 1. Machine learning is not Magic, There are number of algorithms in Mathematics(Actually mathematics is all about applying
#                                                                                algorithms formulaes on Problems)
# 2. When we use formulaes in Mathematics on some set of equations we make a form, a form in which the problem
# exactly looks like the formula we have to implement. Doing same in the Real-world with computers is called Data Mining,
# data mugging, data preparation.
#
# 3. Before applying any machine learning algorithm to Data we have to know about data that how it is
# behaving....(What you mean by behaving?) Keen Knowledge of Statistics and Probability is most required for that.
#
# 4. Why Probability? - in real A data Scientist just make a hypothesis that "May be this is the reason behind everyhting is happening in the system"
# and if you are able to prove that Hypothesis correcet you are the "Thor!- Norse GOD"
#
# 5. How to be Thor- Run various ML models on your data and fond out which one gives most accurate results and then
# use that model for rest of your life. (Rest of life?! - not exactly, we have to update/improve the models each time)
#
# Above points are very raw description came out of my Brain cells, I am sure your's' can prodce much better
# after 3 months of R & D

# %% [markdown]
# A machine learning project may not be linear(just follow one way all te time),
# but it has a number of well known steps:
#
# ## Define Problem.
# ## Prepare Data.
# ## Evaluate Algorithms.
# ## Improve Results.
# ## Present Results.

# %%
import pandas as pd
data_set = pd.read_csv('goog.csv')
data_set.head()
# Out:
#        ﻿Date    Open    High     Low   Close   Volume
# 0  26-Feb-16  708.58  713.43  700.86  705.07  2239978
# 1  25-Feb-16  700.01  705.98  690.58  705.75  1631855
# 2  24-Feb-16  688.92  700.00  680.78  699.56  1958611
# 3  23-Feb-16  701.45  708.40  693.58  695.85  1999699
# 4  22-Feb-16  707.45  713.24  702.51  706.46  1946067

# %%
data_set.describe()
# Out:
#              Open        High         Low       Close        Volume
# count   19.000000   19.000000   19.000000   19.000000  1.900000e+01
# mean   706.714211  715.041579  695.088421  702.947895  3.225008e+06
# std     31.106763   28.434271   25.114096   23.190671  1.572424e+06
# min    667.850000  684.030000  663.060000  678.110000  1.582260e+06
# 25%    689.590000  699.950000  680.465000  683.845000  1.979155e+06
# 50%    700.010000  705.980000  691.380000  699.560000  2.497024e+06
# 75%    709.290000  713.335000  701.360000  707.235000  4.507178e+06
# max    784.500000  789.870000  764.650000  764.650000  6.332431e+06

# %%
data_set.groupby('High').size()
# Out:
# High
# 684.03    1
# 689.35    1
# 693.75    1
# 698.00    1
# 699.90    1
# 700.00    1
# 701.31    1
# 703.08    1
# 703.99    1
# 705.98    1
# 708.40    1
# 709.75    1
# 712.35    1
# 713.24    1
# 713.43    1
# 727.00    1
# 757.86    1
# 774.50    1
# 789.87    1
# dtype: int64

# %%
# %matplotlib inline
data_set.plot() # how to watch open,high,low and close?

# %%
 data_set.plot(subplots=True) # how to make plot more beautiful?
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f646031a690>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f64600ffbd0>], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.plot(data_set['Open'],data_set['High'],data_set['Low'],data_set['Close'])

# %%
data_set.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f645fdeb7d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f645fb559d0>]], dtype=object)

# %%
data_set['Open'].hist()

# %%
new_dataset = (data_set['Open'],data_set['Close'])

# %%
# ikk new dataframe create karo and volume nu chadd ke saare attribute us ch pao

# %%
data_set.plot(kind='box')
plt.show()

# %%
data_set.plot(kind='box',subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f645f650510>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f645f444990>], dtype=object)

# %%
plt.scatter(data_set['Open'],data_set['Close'])

# %%
plt.scatter(data_set['High'],data_set['Low'])

# %%
plt.scatter(data_set['Open'],data_set['Volume'])

# %%
plt.scatter(data_set['Volume'],data_set['Open'])

# %%
plt.scatter(data_set['Volume'],data_set['High'])

# %%
plt.scatter(data_set['Volume'],data_set['Low'])

# %%
plt.scatter(data_set['High'],data_set['Open']) # bingoooo!! this is making some sense ? !! NO?????? :D

# %%
plt.scatter(data_set['Low'],data_set['Close'])

# %%
data_set.values
# Out:
# array([['26-Feb-16', 708.58, 713.43, 700.86, 705.07, 2239978],
#        ['25-Feb-16', 700.01, 705.98, 690.58, 705.75, 1631855],
#        ['24-Feb-16', 688.92, 700.0, 680.78, 699.56, 1958611],
#        ['23-Feb-16', 701.45, 708.4, 693.58, 695.85, 1999699],
#        ['22-Feb-16', 707.45, 713.24, 702.51, 706.46, 1946067],
#        ['19-Feb-16', 695.03, 703.08, 694.05, 700.91, 1582260],
#        ['18-Feb-16', 710.0, 712.35, 696.03, 697.35, 1859130],
#        ['17-Feb-16', 699.0, 709.75, 691.38, 708.4, 2466808],
#        ['16-Feb-16', 692.98, 698.0, 685.05, 691.0, 2497024],
#        ['12-Feb-16', 690.26, 693.75, 678.6, 682.4, 2129831],
#        ['11-Feb-16', 675.0, 689.35, 668.87, 683.11, 3007223],
#        ['10-Feb-16', 686.86, 701.31, 682.13, 684.12, 2627379],
#        ['9-Feb-16', 672.32, 699.9, 668.77, 678.11, 3604335],
#        ['8-Feb-16', 667.85, 684.03, 663.06, 682.74, 4212541],
#        ['5-Feb-16', 703.87, 703.99, 680.15, 683.57, 5069985],
# ...

# %%
from pandas.tools.plotting import scatter_matrix # at last but not least
scatter_matrix(data_set) # kill me!!! :D :P :D I am norse GOD, I can see whole universe!!
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f645eeb5410>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f645e2fefd0>]], dtype=object)

# %%
X = data_set['High'] # this is Pandas Series, We can also convert it into array using numpy.array
Y = data_set['Open']# Why arrays? I just love Fortran!

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
X = np.array(data_set['High'])
Y = np.array(data_set['Open'])

# %%
X.shape,X.size,Y.shape,Y.size
# Out:
# ((19,), 19, (19,), 19)

# %% [markdown]
# # Pending Part
# ## some statistics?
# 1. There are various methods in scipy.stats
# 2. Statsmodel in Python has some good options to look for
# 3. Apply raw Statistics Techniques to your Data!

# %% [markdown]
# # Validation Dataset
#
# write more about validation DataSets and it's' importance

# %%
# A real DataScience comes from lots of  Practice,Research,Curiosity,Fun,Science and madness
from sklearn import cross_validation 
validation_size = 0.20
seed = 7 # What is the meaning of seed here?
X_train,X_validation,Y_train,Y_validation = cross_validation.train_test_split(X,Y,test_size = validation_size,random_state=seed)

# %% [markdown]
# ## test harness ? what is test Harness?
# We will use 10-fold cross validation to estimate accuracy.
#
# This will split our dataset into 10 parts, train on 9 and test on 1 and repeat for all combinations of train-test splits.

# %%
num_folds = 10
num_instances = len(X_train)
seed = 7
scoring = 'accuracy'

# %% [markdown]
# # Let's Apply Models (Most easiet part OR your Journey to Mathematics Starts from here!!) - COnsider this one as serious Advice from whole session

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# Spot Check Algorithms
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
# evaluate each model in turn
results = []
names = []
for name, model in models:
    kfold = cross_validation.KFold(n=num_instances, n_folds=num_folds, random_state=seed)
    cv_results = cross_validation.cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# /home/metal-machine/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-33e8341fa177> in <module>()
#      22 for name, model in models:
#      23     kfold = cross_validation.KFold(n=num_instances, n_folds=num_folds, random_state=seed)
# ---> 24     cv_results = cross_validation.cross_val_score(model, X_train, Y_train, cv=kfold, scoring=scoring)
#      25     results.append(cv_results)
#      26     names.append(name)
#
# ...

# %% [markdown]
# # Select Best model

# %%
# Compare Algorithms
fig = plt.figure()
fig.subtitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0f1c2ef85ee8> in <module>()
#       1 # Compare Algorithms
# ----> 2 fig = plt.figure()
#       3 fig.subtitle('Algorithm Comparison')
#       4 ax = fig.add_subplot(111)
#       5 plt.boxplot(results)
#
# NameError: name 'plt' is not defined

# %%
Sweet way of condensing monstrous amount of information in a one-way street. Thanks!

Just a small thing, you are creating the Kfold inside the loop in the cross validation. Then, you use the same seed to keep the comparison across predictors constant.

That works, but I think it would be better to take it out of the loop. Not only is more efficient, but it is also much immediately clearer that all predictors are using the same Kfold.

You can still justify the use of the seeds in terms of replicability; readers getting the same results on their machines.

Thanks again!
# Out:
#   File "<ipython-input-36-51e0284cd153>", line 1
#     Sweet way of condensing monstrous amount of information in a one-way street. Thanks!
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Selected best model , Now just be a good GOD and write Future :) ;)
# # Make predictions on validation dataset

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, Y_train)
predictions = knn.predict(X_validation)
print(accuracy_score(Y_validation, predictions))
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# /home/metal-machine/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-08221e94f070> in <module>()
#       1 knn = KNeighborsClassifier()
# ----> 2 knn.fit(X_train, Y_train)
#       3 predictions = knn.predict(X_validation)
#       4 print(accuracy_score(Y_validation, predictions))
#       5 print(confusion_matrix(Y_validation, predictions))
#
# /home/metal-machine/anaconda2/lib/python2.7/site-packages/sklearn/neighbors/base.pyc in fit(self, X, y)
#     759         """
#     760         if not isinstance(X, (KDTree, BallTree)):
# ...
